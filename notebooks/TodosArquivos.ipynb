# %%
import pandas as pd
import glob

df = pd.DataFrame({})
files = glob.glob('../build/*.csv')
for file in files:
    df = df.append(pd.read_csv(file, sep=';'))

df.describe()
# Out:
#          ideCadastro  nuCarteiraParlamentar  nuLegislatura  codLegislatura  \
# count  291537.000000          291537.000000       292289.0        292289.0
# mean   138913.052467             296.787859         2015.0            55.0
# std     43432.456552             159.500588            0.0             0.0
# min      4930.000000               1.000000         2015.0            55.0
# 25%     74688.000000             164.000000         2015.0            55.0
# 50%    160544.000000             291.000000         2015.0            55.0
# 75%    178869.000000             443.000000         2015.0            55.0
# max    205234.000000             620.000000         2015.0            55.0
#
#           numSubCota  numEspecificacaoSubCota  indTipoDocumento  \
# count  292289.000000            292289.000000     292289.000000
# mean      331.033487                 0.214192          1.051990
# std       453.869796                 0.420003          1.604018
# ...
